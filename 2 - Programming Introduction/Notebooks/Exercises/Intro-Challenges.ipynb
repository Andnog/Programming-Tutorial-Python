# %% [markdown]
# ___
# # <font color='#ee6c4d'>**Change vocals**</font>
#
# Write a program that changes the vowels `a` to `e` and vice versa in the following sentences:
#
# 1. It didn’t live up to my expectations at the meeting.
# 1. It's rare to find big yards in Japan.
# 1. You‘d better wear a light jacket.
#
# <br>
#
# #### **Output:**
#
# 1. It didn’t liva up to my axpactetions et tha maating.
# 1. It's rera to find big yerds in Jepen.
# 1. You‘d battar waer e light jeckat.
#
# <br>
#
# > Hint: Use replace

# %% [markdown]
# ___
# # <font color='#ee6c4d'>**Word guesser**</font>
#
# Write a program that prints a riddle and then asks you to guess what word it refers to. The word must be valid if it is spelled correctly and it doesn't matter if the whole word or sections of the word are in upper and lower case, it must be considered valid.
#
# <br>
#
# The riddle:
#
# ` I’m tall when I’m young, and I’m short when I’m old. What am I?`
#
# The word to guess:
#
# `candle`
#
# <br>
#
# **Example of valid words**:
#
# Word to guess: candle
#
# Words valid:
# * `"candle"`
# * `"  candle"`
# * `"Candle"`
# * `"CANDLE"`
# * `"canDLE"`
# * `"CANdle"`
# * etc
#
# Words invalid:
# * `"C4ndle"`
# * `"C4ndl3"`
# * `"sail"`
# * `"cand"`
# * etc
#
# <br>
#
# #### **Input:**
#
# * word: Given by the user
#
# <br>
#
# #### **Output:**
#
# If the word were guessed print: `Excelent, the word is candle`, otherwise print `Nice try but it is not the word`.
#
# <br>
#
# > Hint: Print first the riddle and then aks the word

# %% [markdown]
# ___
# # <font color='#ee6c4d'>**Password validatior 1.0**</font>
#
# Write a program that validates a basic password text. The password validator has certain characteristics:
#
# If the pasword is strong it should be between 12 to 18 characters long, if it is medium it should be between 6 to 12 characters long and if it is weak it should be between 2 to 6 characters long.
#
# The program should only ask for the type of password to generate and the password. As a result it should say if it is valid or not.
#
# <br>
#
# #### **Input:**
#
# * type_password: Given by the user. Options: strong, medium or weak
# * password: Given by the user. Any word or sentence
#
# <br>
#
# #### **Output:**
#
# If the password is correct, based on the conditions, print: `Your password is valid`. Otherwise print: `Your password is invalid`.
#
# <br>
#
# > Hint: Remove excess white space at the edges of the text borders

# %% [markdown]
# ___
# # <font color='#ee6c4d'>**Weather 1.0**</font>
#
# Write a program that given a temperature (°C) prints whether it is cold, warm or hot and the sublevel it is at: very cold or cold, normal or very hot. The following range conditions and their printout are in the following table.
#
# <br>
#
# <table> <thead> <tr>
#    <th>Weather</th>
#    <th>Sublevel</th>
#    <th>Range</th>
# </tr> </thead>
# <tbody>
#  <tr>
#   <td align="center">Cold</td>
#   <td align="center">Freezing</td>
#   <td align="center">< 0</td>
#  </tr>
#  <tr>
#   <td align="center">Cold</td>
#   <td align="center">Very Cold</td>
#   <td align="center">0-10</td>
#  </tr>
#  <tr>
#   <td align="center">Cold</td>
#   <td align="center">Barely cold</td>
#   <td align="center">10-20</td>
#  </tr>
#  <tr>
#   <td align="center">Warm</td>
#   <td align="center">Cozy</td>
#   <td align="center">20-30</td>
#  </tr>
#  <tr>
#   <td align="center">Hot</td>
#   <td align="center">Embarrassing</td>
#   <td align="center">30-40</td>
#  </tr>
#  <tr>
#   <td align="center">Hot</td>
#   <td align="center">Very hot</td>
#   <td align="center">> 40</td>
#  </tr>
# </tbody></table>
#
# <br>
#
# #### **Input:**
#
# * temperature: Given by the user. In Fahrenheit (°F)
#
# <br>
#
# #### **Output:**
#
# Print `"The weather is <weather> and <sublevel>"`
#
# <br>
#
# > Hint: Convert °F to °C. $°C = (°F-32)*\frac{5}{9}$

# %% [markdown]
# ___
# # <font color='#ee6c4d'>**CreditLine**</font>
#
# Write a program that asks for three transaction amounts, averages those amounts and returns a credit line amount according to the average. The program must consider the following conditions: the transaction amounts must be rounded to 2 decimal places, the credit line amount must be rounded to hundreds, and it cannot generate a credit line if the average is less than 75.
#
# <br>
#
# #### **Input:**
#
# * transaction_amount_1: Given by the user.
# * transaction_amount_2: Given by the user.
# * transaction_amount_3: Given by the user.
#
# <br>
#
# #### **Output:**
#
# Print if the amount is valid: `"Congratulation, your credit amount is $<creditline_amount>"`, otherwise print: `"Sorry, the transaction amount is not sufficient"`
#
# <br>
#
# > Hint: Use round

# %% [markdown]
# ___
# # <font color='#ee6c4d'>**Body Mass Index (BMI)**</font>
#
# Write a program that calculates the body mass index based on the person's weight and height, and print the interpretation of the result. The interpretation is given by the following table:
#
# <br>
#
# <table> <thead> <tr>
#    <th>Range</th>
#    <td align="center"><18.5</td>
#    <td align="center">18.5 - 24.9</td>
#    <td align="center">25 - 29.9</td>
#    <td align="center">30 - 34.9</td>
#    <td align="center">>35</td>
# </tr> </thead>
# <tbody>
#  <tr>
#   <td align="center"></td>
#   <td align="center">Underweight</td>
#   <td align="center">Normal</td>
#   <td align="center">Overweight</td>
#   <td align="center">Obese</td>
#   <td align="center">Extremely obese</td>
#  </tr>
# </tbody></table>
#
# <br>
#
# #### **Formula:**
#
# $BMI = \frac{weight\_in\_kg}{(height\_in\_m)^2}$
#
# <br>
#
# #### **Input:**
#
# * weight: Given by the user. In Kilograms (Kg)
# * height: Given by the user. In Kilograms (cm)
#
# <br>
#
# #### **Output:**
#
# Print: `"Your BMI is <result> and is <range_result>"`
#
# <br>
#
# > Hint: Convert cm to m
#
# > Hint: Use round in BMI result. (2 decimals places)

# %% [markdown]
# # <font color='#ee6c4d'>**Complete triangle star**</font>
#
# Write a program that performs a complete triangle pattern with the `*` symbol of n levels, the levels depend on the given number.
#
# <br>
#
# #### **Input:**
#
# * number: Given by the user
#
# <br>
#
# #### **Output:**
#
# Complete triangular pattern.
#
# <br>
#
# > Hint: Use nested `for` and double `for`
#
# <br>
#
# #### **Example:**
#
# ```
#  n = 5
#
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *
# ```

# %% [markdown]
# # <font color='#ee6c4d'>**Diamond star**</font>
#
# Write a program that performs a diamon pattern with the `*` symbol of n levels, the levels depend on the given number.
#
# <br>
#
# #### **Input:**
#
# * number: Given by the user
#
# <br>
#
# #### **Output:**
#
# Diamond pattern.
#
# <br>
#
# > Hint: Use nested `for` and double `for`
#
# <br>
#
# #### **Example:**
#
# ```
# n = 5
#
#           *
#         * * *
#       * * * * *
#     * * * * * * *
#   * * * * * * * * *
#     * * * * * * *
#       * * * * *
#         * * *
#           *
# ```
